# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | karymskoye
# Processing Record 6 of Set 1 | hobyo
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | port elizabeth
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | maintirano
# Processing Record 13 of Set 1 | san antonio de pale
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | dawesville
# Processing Record 16 of Set 1 | bargaal
# Processing Record 17 of Set 1 | grytviken
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | santiago de cao
# Processing Record 20 of Set 1 | holualoa
# Processing Record 21 of Set 1 | anadyr
# Processing Record 22 of Set 1 | cockburn town
# Processing Record 23 of Set 1 | remire-montjoly
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | guaruja
# Processing Record 26 of Set 1 | keflavik
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | saipan
# Processing Record 29 of Set 1 | tigpalay
# Processing Record 30 of Set 1 | udachny
# Processing Record 31 of Set 1 | hunchun
# Processing Record 32 of Set 1 | amga
# Processing Record 33 of Set 1 | oriximina
# Processing Record 34 of Set 1 | murun-kuren
# Processing Record 35 of Set 1 | atafu village
# Processing Record 36 of Set 1 | westerland
# Processing Record 37 of Set 1 | vorgashor
# Processing Record 38 of Set 1 | cienfuegos
# Processing Record 39 of Set 1 | utrik
# Processing Record 40 of Set 1 | chincha alta
# Processing Record 41 of Set 1 | cabedelo
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | isafjordur
# Processing Record 44 of Set 1 | klyuchi
# Processing Record 45 of Set 1 | barcelos
# Processing Record 46 of Set 1 | badger
# Processing Record 47 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 48 of Set 1 | hammerfest
# Processing Record 49 of Set 1 | bethel
# Processing Record 50 of Set 1 | bamboo flat
# Processing Record 0 of Set 2 | la ronge
# Processing Record 1 of Set 2 | papatowai
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | beledweyne
# Processing Record 5 of Set 2 | edinburgh of the seven seas
# Processing Record 6 of Set 2 | plastun
# Processing Record 7 of Set 2 | keelung
# Processing Record 8 of Set 2 | kusheriki
# Processing Record 9 of Set 2 | fort mcmurray
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | rongelap
# Processing Record 12 of Set 2 | qapqal
# City not found. Skipping...
# Processing Record 13 of Set 2 | iqaluit
# Processing Record 0 of Set 5 | vilyuchinsk
# Processing Record 1 of Set 5 | bardai
# Processing Record 2 of Set 5 | vila velha
# Processing Record 3 of Set 5 | bushehr
# Processing Record 4 of Set 5 | raseiniai
# Processing Record 5 of Set 5 | verkhnevilyuysk
# Processing Record 6 of Set 5 | amos
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | olinda
# Processing Record 9 of Set 5 | minas de marcona
# Processing Record 10 of Set 5 | lingyuan
# Processing Record 11 of Set 5 | totness
# Processing Record 12 of Set 5 | chiili
# City not found. Skipping...
# Processing Record 13 of Set 5 | cairns city
# City not found. Skipping...
# Processing Record 14 of Set 5 | san luis de la loma
# Processing Record 15 of Set 5 | zilair
# Processing Record 16 of Set 5 | fort bragg
# Processing Record 17 of Set 5 | gamba
# Processing Record 18 of Set 5 | sinabang
# Processing Record 19 of Set 5 | west island
# Processing Record 20 of Set 5 | fortaleza
# Processing Record 21 of Set 5 | bitkine
# Processing Record 22 of Set 5 | lerwick
# Processing Record 23 of Set 5 | buala
# Processing Record 24 of Set 5 | suez
# Processing Record 25 of Set 5 | kavieng
# Processing Record 26 of Set 5 | montmagny
# Processing Record 27 of Set 5 | choyr
# Processing Record 28 of Set 5 | hotan
# Processing Record 29 of Set 5 | perene
# Processing Record 30 of Set 5 | zagora
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | biltine
# Processing Record 33 of Set 5 | gaspe
# Processing Record 34 of Set 5 | bayan nur
# City not found. Skipping...
# Processing Record 35 of Set 5 | ulan-ude
# Processing Record 36 of Set 5 | kalymnos
# Processing Record 37 of Set 5 | eseka
# Processing Record 38 of Set 5 | alenquer
# Processing Record 39 of Set 5 | maragogi
# Processing Record 40 of Set 5 | patnanungan
# Processing Record 41 of Set 5 | kismayo
# Processing Record 42 of Set 5 | quellon
# Processing Record 43 of Set 5 | san patricio
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | dolbeau-mistassini
# Processing Record 46 of Set 5 | ibotirama
# Processing Record 47 of Set 5 | quiberon
# Processing Record 48 of Set 5 | bislig
# Processing Record 49 of Set 5 | bryne
# Processing Record 0 of Set 6 | tadine
# Processing Record 1 of Set 6 | bayanhongor
# Processing Record 2 of Set 6 | tolanaro
# Processing Record 3 of Set 6 | nadi
# Processing Record 4 of Set 6 | alice springs
# Processing Record 5 of Set 6 | sanshui
# Processing Record 6 of Set 6 | buzuluk
# Processing Record 7 of Set 6 | guariba
# Processing Record 8 of Set 6 | zaozersk
# Processing Record 9 of Set 6 | sao gabriel da cachoeira
# Processing Record 10 of Set 6 | belyy yar
# Processing Record 11 of Set 6 | salinopolis
# Processing Record 12 of Set 6 | beatrice
# Processing Record 13 of Set 6 | fukuecho
# Processing Record 14 of Set 6 | sisimiut
# Processing Record 15 of Set 6 | fada
# Processing Record 16 of Set 6 | warrnambool
# Processing Record 17 of Set 6 | laranjeiras do sul
# Processing Record 18 of Set 6 | gotsucho
# Processing Record 19 of Set 6 | hadibu
# Processing Record 20 of Set 6 | durango
# Processing Record 21 of Set 6 | umm kaddadah
# Processing Record 22 of Set 6 | enewetak
# Processing Record 23 of Set 6 | kuching
# Processing Record 24 of Set 6 | aasiaat
# Processing Record 25 of Set 6 | nizhnyaya tavda
# Processing Record 26 of Set 6 | constantia
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | igrim
# Processing Record 29 of Set 6 | tura
# Processing Record 30 of Set 6 | kaliganj
# Processing Record 31 of Set 6 | st. john's
# Processing Record 32 of Set 6 | el calafate
# Processing Record 33 of Set 6 | santa elena de uairen
# Processing Record 34 of Set 6 | hluti
# Processing Record 35 of Set 6 | afaahiti
# Processing Record 36 of Set 6 | al wajh
# Processing Record 37 of Set 6 | fale old settlement
# Processing Record 38 of Set 6 | kaga bandoro
# Processing Record 39 of Set 6 | lospalos
# Processing Record 40 of Set 6 | bonthe
# Processing Record 41 of Set 6 | senador jose porfirio
# Processing Record 42 of Set 6 | vadso
# Processing Record 43 of Set 6 | berdsk
# Processing Record 44 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 45 of Set 6 | songling
# Processing Record 46 of Set 6 | malango
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | tayaman
# Processing Record 49 of Set 6 | kashima-shi
# Processing Record 0 of Set 7 | hengyang
# Processing Record 1 of Set 7 | pisco
# Processing Record 2 of Set 7 | kapuskasing
# Processing Record 3 of Set 7 | dahab
# Processing Record 4 of Set 7 | nizhnyaya poyma
# Processing Record 5 of Set 7 | ghat
# Processing Record 6 of Set 7 | mahajanga
# Processing Record 7 of Set 7 | itoman
# Processing Record 8 of Set 7 | al kharj
# Processing Record 9 of Set 7 | talara
# Processing Record 10 of Set 7 | mahalapye
# Processing Record 11 of Set 7 | jaito
# Processing Record 12 of Set 7 | agua prieta
# Processing Record 13 of Set 7 | papao
# Processing Record 14 of Set 7 | val-d'or
# Processing Record 15 of Set 7 | ebaye
# Processing Record 16 of Set 7 | crane
# Processing Record 17 of Set 7 | manaure
# Processing Record 18 of Set 7 | qeshm
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | mukalla
# Processing Record 21 of Set 7 | forster
# Processing Record 22 of Set 7 | mili
# Processing Record 23 of Set 7 | tchintabaraden
# Processing Record 24 of Set 7 | waitara
# Processing Record 25 of Set 7 | ponmana
# City not found. Skipping...
# Processing Record 26 of Set 7 | susuman
# Processing Record 27 of Set 7 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 28 of Set 7 | kapa'a
# Processing Record 29 of Set 7 | nikolayevsk-on-amure
# Processing Record 30 of Set 7 | illizi
# Processing Record 31 of Set 7 | hamilton
# Processing Record 32 of Set 7 | kuusamo
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | prince rupert
# Processing Record 35 of Set 7 | mogadishu
# Processing Record 36 of Set 7 | santa cruz
# Processing Record 3 of Set 9 | zabid
# Processing Record 4 of Set 9 | gadzhiyevo
# Processing Record 5 of Set 9 | kerikeri
# Processing Record 6 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 7 of Set 9 | raduzhny
# Processing Record 8 of Set 9 | polokwane
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | sao felix do xingu
# Processing Record 11 of Set 9 | ivatsevichy
# Processing Record 12 of Set 9 | tianfu
# Processing Record 13 of Set 9 | tughyl
# Processing Record 14 of Set 9 | kralendijk
# Processing Record 15 of Set 9 | mount pearl
# Processing Record 16 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 17 of Set 9 | natchitoches
# Processing Record 18 of Set 9 | kulhudhuffushi
# Processing Record 19 of Set 9 | ust-tsilma
# Processing Record 20 of Set 9 | camana
# Processing Record 21 of Set 9 | tisul'
# Processing Record 22 of Set 9 | ribeira brava
# Processing Record 23 of Set 9 | berezovyy
# Processing Record 24 of Set 9 | boca do acre
# Processing Record 25 of Set 9 | berbera
# Processing Record 26 of Set 9 | vilhena
# Processing Record 27 of Set 9 | road town
# Processing Record 28 of Set 9 | nova vicosa
# Processing Record 29 of Set 9 | nasir
# Processing Record 30 of Set 9 | kargopol'
# Processing Record 31 of Set 9 | khash
# Processing Record 32 of Set 9 | paredon
# Processing Record 33 of Set 9 | sao caetano de odivelas
# Processing Record 34 of Set 9 | abuja
# Processing Record 35 of Set 9 | callao
# Processing Record 36 of Set 9 | mohyliv-podilskyi
# Processing Record 37 of Set 9 | kenora
# Processing Record 38 of Set 9 | wuwei
# Processing Record 39 of Set 9 | toulepleu guere
# Processing Record 40 of Set 9 | piti village
# Processing Record 41 of Set 9 | burang
# Processing Record 42 of Set 9 | vilyuysk
# Processing Record 43 of Set 9 | urengoy
# Processing Record 44 of Set 9 | pariaman
# Processing Record 45 of Set 9 | cole harbour
# Processing Record 46 of Set 9 | mandera
# Processing Record 47 of Set 9 | casas grandes
# Processing Record 48 of Set 9 | injambakkam
# City not found. Skipping...
# Processing Record 49 of Set 9 | sovetskaya gavan'
# Processing Record 0 of Set 10 | taman rajawali
# City not found. Skipping...
# Processing Record 1 of Set 10 | hit
# Processing Record 2 of Set 10 | sale
# Processing Record 3 of Set 10 | betio village
# Processing Record 4 of Set 10 | nantucket
# Processing Record 5 of Set 10 | whangarei
# Processing Record 6 of Set 10 | labinsk
# Processing Record 7 of Set 10 | aral
# Processing Record 8 of Set 10 | tegal
# Processing Record 9 of Set 10 | labytnangi
# Processing Record 10 of Set 10 | masina
# Processing Record 11 of Set 10 | polyarnyy
# Processing Record 12 of Set 10 | tamandare
# Processing Record 13 of Set 10 | nadym
# Processing Record 14 of Set 10 | broome
# Processing Record 15 of Set 10 | angaur state
# Processing Record 16 of Set 10 | vernon
# Processing Record 17 of Set 10 | inarajan village
# Processing Record 18 of Set 10 | mossel bay
# Processing Record 19 of Set 10 | tinajo
# Processing Record 20 of Set 10 | yeppoon
# Processing Record 21 of Set 10 | sao joao da barra
# Processing Record 22 of Set 10 | tvoroyri
# Processing Record 23 of Set 10 | magistral'nyy
# Processing Record 24 of Set 10 | severnoye
# Processing Record 25 of Set 10 | chimore
# Processing Record 26 of Set 10 | chilca
# Processing Record 27 of Set 10 | kununurra
# Processing Record 28 of Set 10 | qui nhon
# Processing Record 29 of Set 10 | darovskoy
# Processing Record 30 of Set 10 | laguna
# Processing Record 31 of Set 10 | wabag
# Processing Record 32 of Set 10 | fort st. john
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | palapag
# Processing Record 35 of Set 10 | mount isa
# Processing Record 36 of Set 10 | yangambi
# Processing Record 37 of Set 10 | queenstown
# Processing Record 38 of Set 10 | pitimbu
# Processing Record 39 of Set 10 | labrador city
# Processing Record 40 of Set 10 | torghay
# Processing Record 41 of Set 10 | praia
# Processing Record 42 of Set 10 | gizo
# Processing Record 43 of Set 10 | mazagao
# Processing Record 44 of Set 10 | portland
# Processing Record 45 of Set 10 | seven pagodas
# Processing Record 46 of Set 10 | qom
# Processing Record 47 of Set 10 | kashkhatau
# Processing Record 48 of Set 10 | huarmey
# Processing Record 49 of Set 10 | tamanrasset
# Processing Record 0 of Set 11 | nerchinsk
# Processing Record 1 of Set 11 | amalapuram
# Processing Record 2 of Set 11 | upata
# Processing Record 3 of Set 11 | mosfellsbaer
# Processing Record 4 of Set 11 | san luis
# Processing Record 5 of Set 11 | aioun
# Processing Record 6 of Set 11 | daru
# Processing Record 7 of Set 11 | jolo
# Processing Record 8 of Set 11 | babolsar
# Processing Record 9 of Set 11 | port blair
# Processing Record 10 of Set 11 | lihue
# Processing Record 11 of Set 11 | lakatoro
# Processing Record 12 of Set 11 | priargunsk
# Processing Record 13 of Set 11 | moapa valley
# Processing Record 14 of Set 11 | crieff
# Processing Record 15 of Set 11 | cidade velha
# Processing Record 16 of Set 11 | talakan
# Processing Record 17 of Set 11 | tefe
# Processing Record 18 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 19 of Set 11 | dabakala
# Processing Record 20 of Set 11 | eyl
# Processing Record 21 of Set 11 | berlin
# Processing Record 22 of Set 11 | miandrivazo
# Processing Record 23 of Set 11 | minot air force base
# Processing Record 24 of Set 11 | srandakan
# Processing Record 25 of Set 11 | marshalltown
# Processing Record 26 of Set 11 | es castell
# Processing Record 27 of Set 11 | cova figueira
# Processing Record 28 of Set 11 | paita
# Processing Record 29 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 30 of Set 11 | quatre cocos
# Processing Record 31 of Set 11 | tsiombe
# Processing Record 32 of Set 11 | salym
# Processing Record 33 of Set 11 | griffith
# Processing Record 34 of Set 11 | manzhouli
# Processing Record 35 of Set 11 | liman
# Processing Record 36 of Set 11 | kaintragarh
# Processing Record 37 of Set 11 | port macquarie
# Processing Record 38 of Set 11 | noshiro
# Processing Record 39 of Set 11 | xai-xai
# Processing Record 40 of Set 11 | isoka
# Processing Record 41 of Set 11 | alesund
# Processing Record 42 of Set 11 | qingdao
# Processing Record 43 of Set 11 | pangody
# Processing Record 44 of Set 11 | moyynkum
# Processing Record 45 of Set 11 | tibro
# Processing Record 46 of Set 11 | ta`u
# Processing Record 47 of Set 11 | male
# Processing Record 48 of Set 11 | mar del plata
# Processing Record 49 of Set 11 | luanco
# Processing Record 0 of Set 12 | uglegorsk
# Processing Record 1 of Set 12 | kachug
# Processing Record 2 of Set 12 | ban karon
# Processing Record 3 of Set 12 | bubaque
# Processing Record 4 of Set 12 | nogliki
# Processing Record 5 of Set 12 | hazorasp
# Processing Record 6 of Set 12 | nuevo ideal
# Processing Record 7 of Set 12 | osh
# Processing Record 8 of Set 12 | lake monticello
# Processing Record 9 of Set 12 | nili
# Processing Record 10 of Set 12 | hargeysa
# Processing Record 11 of Set 12 | harran
# Processing Record 12 of Set 12 | palikir - national government center
# Processing Record 13 of Set 12 | naracoorte
# Processing Record 14 of Set 12 | santa barbara
# Processing Record 15 of Set 12 | kourou
# Processing Record 16 of Set 12 | porto novo
# Processing Record 17 of Set 12 | adis zemen
# Processing Record 18 of Set 12 | sandnessjoen
# Processing Record 19 of Set 12 | tionk essil
# Processing Record 20 of Set 12 | geringswalde
# Processing Record 21 of Set 12 | pacific grove
# Processing Record 22 of Set 12 | kristiansund
# Processing Record 23 of Set 12 | chhor
# Processing Record 24 of Set 12 | khanty-mansiysk
# Processing Record 25 of Set 12 | buchanan
# Processing Record 26 of Set 12 | zeya
# Processing Record 27 of Set 12 | ain sefra
# Processing Record 28 of Set 12 | lukolela
# Processing Record 29 of Set 12 | fazilka
# Processing Record 30 of Set 12 | tamala
# Processing Record 31 of Set 12 | ruteng
# Processing Record 32 of Set 12 | illela
# Processing Record 33 of Set 12 | irtyshsk
# Processing Record 34 of Set 12 | marco
# Processing Record 35 of Set 12 | hawkesbury
# Processing Record 36 of Set 12 | peterhead
# Processing Record 37 of Set 12 | al khaburah
# Processing Record 38 of Set 12 | puerto aysen
# Processing Record 39 of Set 12 | don sak
# Processing Record 40 of Set 12 | mao
# Processing Record 41 of Set 12 | asbe teferi
# Processing Record 42 of Set 12 | zhengjiatun
# Processing Record 43 of Set 12 | fassberg
# Processing Record 44 of Set 12 | viedma
# Processing Record 45 of Set 12 | pontal do parana
# Processing Record 46 of Set 12 | lae
# Processing Record 47 of Set 12 | bahia de kino
# Processing Record 48 of Set 12 | kondoa
# Processing Record 49 of Set 12 | ijuw
# City not found. Skipping...
# Processing Record 0 of Set 13 | shenjiamen
# Processing Record 1 of Set 13 | brokopondo
# Processing Record 2 of Set 13 | karratha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          adamstown -25.0660 -130.1015     20.35        69         100
# 1           waitangi -43.9535 -176.5597     13.79        96          42
# 2  port-aux-francais -49.3500   70.2167      2.62        70          89
# 3      blackmans bay -43.0167  147.3167      9.07        76          13
# 4         karymskoye  51.6167  114.3500     -6.08        97         100
#
#    Wind Speed Country        Date
# 0        6.80      PN  1729709322
# 1        1.34      NZ  1729709323
# 2       13.92      TF  1729709324
# 3        6.33      AU  1729709325
# 4        0.57      RU  1729709326

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     20.35        69         100
# 1                 waitangi -43.9535 -176.5597     13.79        96          42
# 2        port-aux-francais -49.3500   70.2167      2.62        70          89
# 3            blackmans bay -43.0167  147.3167      9.07        76          13
# 4               karymskoye  51.6167  114.3500     -6.08        97         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.80      PN  1729709322
# 1              1.34      NZ  1729709323
# 2             13.92      TF  1729709324
# 3              6.33      AU  1729709325
# 4              0.57      RU  1729709326

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidth = .75)


# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidth = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidth = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidth = .75)

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed Plot")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4         karymskoye  51.6167  114.3500     -6.08        97         100
# 5              hobyo   5.3505   48.5268     26.35        87          22
# 8             kodiak  57.7900 -152.4072      6.73        49           0
# 10       yellowknife  62.4560 -114.3525      1.34        87          20
# 13        georgetown   5.4112  100.3354     26.97        78          20
#
#          Wind Speed Country        Date
# City_ID
# 4              0.57      RU  1729709326
# 5              8.89      SO  1729709327
# 8              3.09      US  1729709092
# 10             5.66      CA  1729709333
# 13             1.54      MY  1729709238

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015     20.35        69         100
# 1                 waitangi -43.9535 -176.5597     13.79        96          42
# 2        port-aux-francais -49.3500   70.2167      2.62        70          89
# 3            blackmans bay -43.0167  147.3167      9.07        76          13
# 6              east london -33.0153   27.9116     16.52        94           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.80      PN  1729709322
# 1              1.34      NZ  1729709323
# 2             13.92      TF  1729709324
# 3              6.33      AU  1729709325
# 6              1.54      ZA  1729709328

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
linear_equation = linear_regression[0] * northern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
northern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Max Temp',)

plt.plot(
    northern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Northen Hemisphere: City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature Celcius')
plt.show()
# Out:
# The r-squared is: -0.845

# %%
# Linear regression on Southern Hemisphere
linear_regression = linregress(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
linear_equation = linear_regression[0] * southern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
southern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Max Temp',)
    

plt.plot(
    southern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Southern Hemisphere: City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature Celcius')
plt.show()
# Out:
# The r-squared is: 0.706

# %% [raw]
# **Discussion about the linear relationship:The Northern Hemisphere has a declining linear relationship with the temperature as the latitude goes higher. The Southern Hemisphere has an inclining linear relation with the rising temperatures and latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression = linregress(northern_hemi_df["Lat"], northern_hemi_df["Humidity"].astype('float'))
linear_equation = linear_regression[0] * northern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
northern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Humidity',)

plt.plot(
    northern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Northen Hemisphere: City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()
# Out:
# The r-squared is: 0.275

# %%
# Southern Hemisphere
linear_regression = linregress(southern_hemi_df['Lat'], southern_hemi_df['Humidity'].astype('float'))
linear_equation = linear_regression[0] * southern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
southern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Humidity',)

plt.plot(
    southern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Southern Hemisphere: City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()
# Out:
# The r-squared is: -0.056

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, as the city latitude increases the humidity levels also increase. But in the southern hemispher, the linear relationship is not very significant as it but it is still considered a negative relationship.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression = linregress(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'].astype('float'))
linear_equation = linear_regression[0] * northern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
northern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Cloudiness',)

plt.plot(
    northern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Northen Hemisphere: City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()
# Out:
# The r-squared is: 0.155

# %%
# Southern Hemisphere
linear_regression = linregress(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'].astype('float'))
linear_equation = linear_regression[0] * southern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
southern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Cloudiness',)

plt.plot(
    southern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')

plt.title('Southern Hemisphere: City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()
# Out:
# The r-squared is: 0.179

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres have a positive linear relationship between city latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression = linregress(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'].astype('float'))
linear_equation = linear_regression[0] * northern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
northern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Wind Speed',)
plt.plot(
    northern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')
plt.title('Northen Hemisphere: City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mps)')
plt.show()
# Out:
# The r-squared is: 0.113

# %%
# Southern Hemisphere
linear_regression = linregress(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'].astype('float'))
linear_equation = linear_regression[0] * southern_hemi_df['Lat'] + linear_regression[1]
line_eq = f'y = {str(round(linear_regression[0],2))} x + {str(round(linear_regression[1],2))}'

print(f'The r-squared is: {round(linear_regression[2],3)}')
southern_hemi_df.plot.scatter(
    x = 'Lat',
    y = 'Wind Speed',)
plt.plot(
    southern_hemi_df['Lat'],
    linear_equation,
    linewidth = 3,
    color = 'black')
plt.title('Southern Hemisphere: City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mps)')
plt.show()
# Out:
# The r-squared is: -0.129

# %% [markdown]
# **Discussion about the linear relationship:** The northern hemisphere has a slightly positive linear relation while the southern hemisphere is a more of a negative relation.
